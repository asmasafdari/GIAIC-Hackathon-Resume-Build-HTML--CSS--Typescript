# %% [markdown]
# <a href="https://colab.research.google.com/github/asmasafdari/GIAIC-Hackathon-Resume-Build-HTML--CSS--Typescript/blob/main/02agreementbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def main():
    favorite_animal = input("What's your favorite animal? ")

    print(f"My favorite animal is also {favorite_animal}!")

if __name__ == '__main__':
    main()
